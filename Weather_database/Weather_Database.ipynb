# %%
import numpy as np 
from citipy import citipy
import gmaps
import requests
import pandas as pd 
from datetime import datetime

from chconfig import weather_api_key
from chconfig import g_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy
import time

# %%
# Get the nearest city using the citipy module.
cities = list()
for coord in coordinates:
    cities_name = citipy.nearest_city(coord[0],coord[1]).city_name
    if cities_name not in cities:
        cities.append(cities_name)
print(cities[:10], 'Generate', len(cities))
# Out:
# ['teahupoo', 'sabla', 'hilo', 'puerto ayora', 'ushuaia', 'bengkulu', 'kamphaeng phet', 'kavaratti', 'new norfolk', 'charlestown'] Generate 728

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 728

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        weather_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": weather_description,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | teahupoo
# Processing Record 2 of Set 1 | sabla
# Processing Record 3 of Set 1 | hilo
# Processing Record 4 of Set 1 | puerto ayora
# Processing Record 5 of Set 1 | ushuaia
# Processing Record 6 of Set 1 | bengkulu
# Processing Record 7 of Set 1 | kamphaeng phet
# Processing Record 8 of Set 1 | kavaratti
# Processing Record 9 of Set 1 | new norfolk
# Processing Record 10 of Set 1 | charlestown
# Processing Record 11 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 12 of Set 1 | bolungarvik
# City not found. Skipping...
# Processing Record 13 of Set 1 | benguela
# Processing Record 14 of Set 1 | dikson
# Processing Record 15 of Set 1 | mandurah
# Processing Record 16 of Set 1 | bambanglipuro
# Processing Record 17 of Set 1 | kodiak
# Processing Record 18 of Set 1 | pimentel
# Processing Record 19 of Set 1 | ilulissat
# Processing Record 20 of Set 1 | vaini
# Processing Record 21 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 22 of Set 1 | ancud
# Processing Record 23 of Set 1 | san jeronimo
# Processing Record 24 of Set 1 | ambon
# Processing Record 25 of Set 1 | tasiilaq
# Processing Record 26 of Set 1 | qaanaaq
# Processing Record 27 of Set 1 | arraial do cabo
# Processing Record 28 of Set 1 | mpanda
# Processing Record 29 of Set 1 | kama
# Processing Record 30 of Set 1 | caravelas
# Processing Record 31 of Set 1 | esna
# Processing Record 32 of Set 1 | marsa matruh
# Processing Record 33 of Set 1 | andrews
# Processing Record 34 of Set 1 | hobart
# Processing Record 35 of Set 1 | atuona
# Processing Record 36 of Set 1 | jamestown
# Processing Record 37 of Set 1 | hauterive
# Processing Record 38 of Set 1 | hirtshals
# Processing Record 39 of Set 1 | souillac
# Processing Record 40 of Set 1 | nikolskoye
# Processing Record 41 of Set 1 | bay city
# Processing Record 42 of Set 1 | georgetown
# Processing Record 43 of Set 1 | praya
# Processing Record 44 of Set 1 | havoysund
# Processing Record 45 of Set 1 | pevek
# Processing Record 46 of Set 1 | kruisfontein
# Processing Record 47 of Set 1 | mataura
# Processing Record 48 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 49 of Set 1 | panguipulli
# Processing Record 50 of Set 1 | saldanha
# Processing Record 1 of Set 2 | port hedland
# Processing Record 2 of Set 2 | castro
# Processing Record 3 of Set 2 | sedelnikovo
# City not found. Skipping...
# Processing Record 4 of Set 2 | nata
# Processing Record 5 of Set 2 | hervey bay
# Processing Record 6 of Set 2 | chokurdakh
# Processing Record 7 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 8 of Set 2 | port elizabeth
# Processing Record 9 of Set 2 | kushima
# Processing Record 10 of Set 2 | mahebourg
# Processing Record 11 of Set 2 | puerto baquerizo moreno
# Processing Record 12 of Set 2 | bunol
# Processing Record 13 of Set 2 | busselton
# Processing Record 14 of Set 2 | fort nelson
# Processing Record 15 of Set 2 | rikitea
# Processing Record 16 of Set 2 | scottsbluff
# Processing Record 17 of Set 2 | el rosario
# Processing Record 18 of Set 2 | thompson
# Processing Record 19 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 20 of Set 2 | bredasdorp
# Processing Record 21 of Set 2 | sao joao da barra
# Processing Record 22 of Set 2 | upernavik
# Processing Record 23 of Set 2 | barcelos
# Processing Record 24 of Set 2 | baoning
# Processing Record 25 of Set 2 | kurayoshi
# Processing Record 26 of Set 2 | shingu
# Processing Record 27 of Set 2 | bluff
# Processing Record 28 of Set 2 | verkhnyaya inta
# Processing Record 29 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 30 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 31 of Set 2 | geraldton
# Processing Record 32 of Set 2 | paamiut
# Processing Record 33 of Set 2 | bathsheba
# Processing Record 34 of Set 2 | nanchang
# Processing Record 35 of Set 2 | cabo san lucas
# Processing Record 36 of Set 2 | livingston
# Processing Record 37 of Set 2 | tiksi
# Processing Record 38 of Set 2 | huilong
# Processing Record 39 of Set 2 | verkhnevilyuysk
# Processing Record 40 of Set 2 | yaan
# Processing Record 41 of Set 2 | ponta do sol
# Processing Record 42 of Set 2 | henties bay
# Processing Record 43 of Set 2 | albany
# Processing Record 44 of Set 2 | barrow
# Processing Record 45 of Set 2 | guerrero negro
# Processing Record 46 of Set 2 | pisco
# Processing Record 47 of Set 2 | kaitangata
# Processing Record 48 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 49 of Set 2 | phetchaburi
# Processing Record 50 of Set 2 | guanare
# Processing Record 1 of Set 3 | ugoofaaru
# Processing Record 2 of Set 3 | atar
# Processing Record 3 of Set 3 | dwarka
# Processing Record 4 of Set 3 | ribeira grande
# Processing Record 5 of Set 3 | angelopolis
# Processing Record 6 of Set 3 | tuktoyaktuk
# Processing Record 7 of Set 3 | teopisca
# Processing Record 8 of Set 3 | barmer
# Processing Record 9 of Set 3 | marly
# Processing Record 10 of Set 3 | avarua
# Processing Record 11 of Set 3 | half moon bay
# Processing Record 12 of Set 3 | butaritari
# Processing Record 13 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 14 of Set 3 | kiunga
# Processing Record 15 of Set 3 | lompoc
# Processing Record 16 of Set 3 | fairbanks
# Processing Record 17 of Set 3 | ocher
# Processing Record 18 of Set 3 | punta arenas
# Processing Record 19 of Set 3 | hasaki
# Processing Record 20 of Set 3 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 21 of Set 3 | baruun-urt
# Processing Record 22 of Set 3 | santa cruz
# Processing Record 23 of Set 3 | mogadishu
# Processing Record 24 of Set 3 | srednekolymsk
# Processing Record 25 of Set 3 | berlevag
# Processing Record 26 of Set 3 | bam
# Processing Record 27 of Set 3 | longyearbyen
# Processing Record 28 of Set 3 | mar del plata
# Processing Record 29 of Set 3 | miles city
# Processing Record 30 of Set 3 | coari
# Processing Record 31 of Set 3 | khatanga
# Processing Record 32 of Set 3 | santa isabel do rio negro
# Processing Record 33 of Set 3 | stornoway
# Processing Record 34 of Set 3 | yellowknife
# Processing Record 35 of Set 3 | adrar
# Processing Record 36 of Set 3 | severo-kurilsk
# Processing Record 37 of Set 3 | parkersburg
# Processing Record 38 of Set 3 | kasongo-lunda
# Processing Record 39 of Set 3 | kapaa
# Processing Record 40 of Set 3 | bubaque
# Processing Record 41 of Set 3 | olafsvik
# Processing Record 42 of Set 3 | komsomolskiy
# Processing Record 43 of Set 3 | provideniya
# Processing Record 44 of Set 3 | yumen
# Processing Record 45 of Set 3 | porto novo
# Processing Record 46 of Set 3 | bekhtery
# Processing Record 47 of Set 3 | sisimiut
# Processing Record 48 of Set 3 | chanute
# Processing Record 49 of Set 3 | susa
# Processing Record 50 of Set 3 | tabulbah
# City not found. Skipping...
# Processing Record 1 of Set 4 | dunmore east
# Processing Record 2 of Set 4 | carnarvon
# Processing Record 3 of Set 4 | high prairie
# Processing Record 4 of Set 4 | maple creek
# Processing Record 5 of Set 4 | hithadhoo
# Processing Record 6 of Set 4 | manhattan
# Processing Record 7 of Set 4 | pumiao
# Processing Record 8 of Set 4 | ardistan
# City not found. Skipping...
# Processing Record 9 of Set 4 | bonfim
# Processing Record 10 of Set 4 | chuy
# Processing Record 11 of Set 4 | hermanus
# Processing Record 12 of Set 4 | moroto
# Processing Record 13 of Set 4 | nyurba
# Processing Record 14 of Set 4 | klaksvik
# Processing Record 15 of Set 4 | ileza
# Processing Record 16 of Set 4 | olinda
# Processing Record 17 of Set 4 | micheweni
# Processing Record 18 of Set 4 | saint george
# Processing Record 19 of Set 4 | katherine
# Processing Record 20 of Set 4 | belmonte
# Processing Record 21 of Set 4 | lebu
# Processing Record 22 of Set 4 | chernolesskoye
# Processing Record 23 of Set 4 | zhangye
# Processing Record 24 of Set 4 | salta
# Processing Record 25 of Set 4 | caraballeda
# Processing Record 26 of Set 4 | colesberg
# Processing Record 27 of Set 4 | gat
# Processing Record 28 of Set 4 | port alfred
# Processing Record 29 of Set 4 | klyuchi
# Processing Record 30 of Set 4 | mayumba
# Processing Record 31 of Set 4 | seymchan
# Processing Record 32 of Set 4 | vidalia
# Processing Record 33 of Set 4 | makung
# City not found. Skipping...
# Processing Record 34 of Set 4 | ayan
# Processing Record 35 of Set 4 | yerbogachen
# Processing Record 36 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 37 of Set 4 | saint-augustin
# Processing Record 38 of Set 4 | bharatpur
# Processing Record 39 of Set 4 | port macquarie
# Processing Record 40 of Set 4 | narsaq
# Processing Record 41 of Set 4 | hualmay
# Processing Record 42 of Set 4 | sao miguel
# Processing Record 43 of Set 4 | kavieng
# Processing Record 44 of Set 4 | cheuskiny
# City not found. Skipping...
# Processing Record 45 of Set 4 | lagoa
# Processing Record 46 of Set 4 | sao filipe
# Processing Record 47 of Set 4 | zhigansk
# Processing Record 48 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 49 of Set 4 | aykhal
# Processing Record 50 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 1 of Set 5 | antofagasta
# Processing Record 2 of Set 5 | paracuru
# Processing Record 3 of Set 5 | luderitz
# Processing Record 4 of Set 5 | antonina
# Processing Record 5 of Set 5 | cape town
# Processing Record 6 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 7 of Set 5 | abha
# Processing Record 8 of Set 5 | ibra
# Processing Record 9 of Set 5 | salalah
# Processing Record 10 of Set 5 | airai
# Processing Record 11 of Set 5 | pervomayskoye
# Processing Record 12 of Set 5 | portland
# Processing Record 13 of Set 5 | mamallapuram
# Processing Record 14 of Set 5 | saskylakh
# Processing Record 15 of Set 5 | kismayo
# Processing Record 16 of Set 5 | nishihara
# Processing Record 17 of Set 5 | emirdag
# Processing Record 18 of Set 5 | litovko
# Processing Record 19 of Set 5 | san ramon
# Processing Record 20 of Set 5 | ondjiva
# Processing Record 21 of Set 5 | aksu
# Processing Record 22 of Set 5 | saint-philippe
# Processing Record 23 of Set 5 | yeppoon
# Processing Record 24 of Set 5 | cherskiy
# Processing Record 25 of Set 5 | sunrise manor
# Processing Record 26 of Set 5 | east london
# Processing Record 27 of Set 5 | jalu
# Processing Record 28 of Set 5 | panjab
# Processing Record 29 of Set 5 | brigantine
# Processing Record 30 of Set 5 | kushiro
# Processing Record 31 of Set 5 | tura
# Processing Record 32 of Set 5 | mount gambier
# Processing Record 33 of Set 5 | vilhena
# Processing Record 34 of Set 5 | davila
# Processing Record 35 of Set 5 | rochegda
# Processing Record 36 of Set 5 | vanimo
# Processing Record 37 of Set 5 | naryan-mar
# Processing Record 38 of Set 5 | geresk
# City not found. Skipping...
# Processing Record 39 of Set 5 | ust-nera
# Processing Record 40 of Set 5 | tarboro
# Processing Record 41 of Set 5 | bethel
# Processing Record 42 of Set 5 | beloha
# Processing Record 43 of Set 5 | aflu
# City not found. Skipping...
# Processing Record 44 of Set 5 | tabuny
# Processing Record 45 of Set 5 | broken hill
# Processing Record 46 of Set 5 | kerrobert
# Processing Record 47 of Set 5 | penalva
# Processing Record 48 of Set 5 | dekoa
# City not found. Skipping...
# Processing Record 49 of Set 5 | isiolo
# Processing Record 50 of Set 5 | wanaka
# Processing Record 1 of Set 6 | salinopolis
# Processing Record 2 of Set 6 | kudahuvadhoo
# Processing Record 3 of Set 6 | eirunepe
# Processing Record 4 of Set 6 | esperance
# Processing Record 5 of Set 6 | yar-sale
# Processing Record 6 of Set 6 | santa fe
# Processing Record 7 of Set 6 | aklavik
# Processing Record 8 of Set 6 | kuche
# City not found. Skipping...
# Processing Record 9 of Set 6 | goderich
# Processing Record 10 of Set 6 | myitkyina
# Processing Record 11 of Set 6 | pontes e lacerda
# Processing Record 12 of Set 6 | amberieu-en-bugey
# Processing Record 13 of Set 6 | u thong
# Processing Record 14 of Set 6 | nanortalik
# Processing Record 15 of Set 6 | mount isa
# Processing Record 16 of Set 6 | bambous virieux
# Processing Record 17 of Set 6 | prainha
# Processing Record 18 of Set 6 | catamarca
# Processing Record 19 of Set 6 | samalaeulu
# City not found. Skipping...
# Processing Record 20 of Set 6 | porosozero
# Processing Record 21 of Set 6 | palmer
# Processing Record 22 of Set 6 | kichera
# Processing Record 23 of Set 6 | sayyan
# Processing Record 24 of Set 6 | sapa
# Processing Record 25 of Set 6 | burica
# City not found. Skipping...
# Processing Record 26 of Set 6 | kahului
# Processing Record 27 of Set 6 | victoria
# Processing Record 28 of Set 6 | batemans bay
# Processing Record 29 of Set 6 | tautira
# Processing Record 30 of Set 6 | ketchikan
# Processing Record 31 of Set 6 | roald
# Processing Record 32 of Set 6 | neiafu
# Processing Record 33 of Set 6 | norfolk
# Processing Record 34 of Set 6 | linqiong
# Processing Record 35 of Set 6 | margate
# Processing Record 36 of Set 6 | ostrovnoy
# Processing Record 37 of Set 6 | natal
# Processing Record 38 of Set 6 | general pico
# Processing Record 39 of Set 6 | nadym
# Processing Record 40 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 41 of Set 6 | san policarpo
# Processing Record 42 of Set 6 | roebourne
# Processing Record 43 of Set 6 | port shepstone
# Processing Record 44 of Set 6 | kenitra
# Processing Record 45 of Set 6 | novyy urengoy
# Processing Record 46 of Set 6 | tamayo
# Processing Record 47 of Set 6 | brae
# Processing Record 48 of Set 6 | fortuna
# Processing Record 49 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 50 of Set 6 | lakewood
# Processing Record 1 of Set 7 | richards bay
# Processing Record 2 of Set 7 | naze
# Processing Record 3 of Set 7 | santo tomas
# Processing Record 4 of Set 7 | sovetskaya gavan
# Processing Record 5 of Set 7 | coahuayana
# Processing Record 6 of Set 7 | olga
# Processing Record 7 of Set 7 | moldovenesti
# Processing Record 8 of Set 7 | elat
# Processing Record 9 of Set 7 | touros
# Processing Record 10 of Set 7 | tazmalt
# Processing Record 11 of Set 7 | rio tercero
# Processing Record 12 of Set 7 | voka
# Processing Record 13 of Set 7 | torbay
# Processing Record 14 of Set 7 | bayan
# Processing Record 15 of Set 7 | kaspiysk
# Processing Record 16 of Set 7 | moose factory
# Processing Record 17 of Set 7 | vernon
# Processing Record 18 of Set 7 | demba
# Processing Record 19 of Set 7 | bardiyah
# Processing Record 20 of Set 7 | vila franca do campo
# Processing Record 21 of Set 7 | san cristobal
# Processing Record 22 of Set 7 | dukat
# Processing Record 23 of Set 7 | sinjah
# City not found. Skipping...
# Processing Record 24 of Set 7 | kaeo
# Processing Record 25 of Set 7 | valparaiso
# Processing Record 26 of Set 7 | itoman
# Processing Record 27 of Set 7 | vardo
# Processing Record 28 of Set 7 | port blair
# Processing Record 29 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 30 of Set 7 | ipora
# Processing Record 31 of Set 7 | tazovskiy
# Processing Record 32 of Set 7 | honningsvag
# Processing Record 33 of Set 7 | vila velha
# Processing Record 34 of Set 7 | moree
# Processing Record 35 of Set 7 | kedrovka
# Processing Record 36 of Set 7 | havre-saint-pierre
# Processing Record 37 of Set 7 | hofn
# Processing Record 38 of Set 7 | manacapuru
# Processing Record 39 of Set 7 | opuwo
# Processing Record 40 of Set 7 | axim
# Processing Record 41 of Set 7 | baker city
# Processing Record 42 of Set 7 | ahipara
# Processing Record 43 of Set 7 | cidreira
# Processing Record 44 of Set 7 | rodrigues alves
# Processing Record 45 of Set 7 | coquimbo
# Processing Record 46 of Set 7 | katsuura
# Processing Record 47 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 48 of Set 7 | mandera
# Processing Record 49 of Set 7 | urumqi
# Processing Record 50 of Set 7 | setermoen
# Processing Record 1 of Set 8 | alofi
# Processing Record 2 of Set 8 | almaznyy
# Processing Record 3 of Set 8 | sitka
# Processing Record 4 of Set 8 | pochutla
# Processing Record 5 of Set 8 | karamay
# City not found. Skipping...
# Processing Record 6 of Set 8 | camopi
# Processing Record 7 of Set 8 | khani
# Processing Record 8 of Set 8 | linjiang
# Processing Record 9 of Set 8 | trairi
# Processing Record 10 of Set 8 | evensk
# Processing Record 11 of Set 8 | vila
# Processing Record 12 of Set 8 | arman
# Processing Record 13 of Set 8 | grindavik
# Processing Record 14 of Set 8 | whitehorse
# Processing Record 15 of Set 8 | shache
# Processing Record 16 of Set 8 | emba
# Processing Record 17 of Set 8 | masallatah
# Processing Record 18 of Set 8 | port lincoln
# Processing Record 19 of Set 8 | canton
# Processing Record 20 of Set 8 | sumbawa
# City not found. Skipping...
# Processing Record 21 of Set 8 | abu dhabi
# Processing Record 22 of Set 8 | praia da vitoria
# Processing Record 23 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 24 of Set 8 | mao
# Processing Record 25 of Set 8 | hay river
# Processing Record 26 of Set 8 | dingle
# Processing Record 27 of Set 8 | pacific grove
# Processing Record 28 of Set 8 | sacama
# Processing Record 29 of Set 8 | vao
# Processing Record 30 of Set 8 | khonsar
# City not found. Skipping...
# Processing Record 31 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 32 of Set 8 | broadstairs
# Processing Record 33 of Set 8 | skibbereen
# Processing Record 34 of Set 8 | lorengau
# Processing Record 35 of Set 8 | gerash
# Processing Record 36 of Set 8 | keffi
# Processing Record 37 of Set 8 | gravdal
# Processing Record 38 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 39 of Set 8 | moses lake
# Processing Record 40 of Set 8 | hambantota
# Processing Record 41 of Set 8 | anadyr
# Processing Record 42 of Set 8 | ulaangom
# Processing Record 43 of Set 8 | khandyga
# Processing Record 44 of Set 8 | blairmore
# Processing Record 45 of Set 8 | prince rupert
# Processing Record 46 of Set 8 | sinnamary
# Processing Record 47 of Set 8 | marawi
# Processing Record 48 of Set 8 | dali
# Processing Record 49 of Set 8 | tadine
# Processing Record 50 of Set 8 | rosetown
# Processing Record 1 of Set 9 | ngukurr
# City not found. Skipping...
# Processing Record 2 of Set 9 | fengcheng
# Processing Record 3 of Set 9 | puerto madryn
# Processing Record 4 of Set 9 | smoky lake
# Processing Record 5 of Set 9 | xai-xai
# Processing Record 6 of Set 9 | labuhan
# Processing Record 7 of Set 9 | we
# City not found. Skipping...
# Processing Record 8 of Set 9 | vanavara
# Processing Record 9 of Set 9 | bolshaya martynovka
# Processing Record 10 of Set 9 | mana
# Processing Record 11 of Set 9 | alenquer
# Processing Record 12 of Set 9 | kamaishi
# Processing Record 13 of Set 9 | bur gabo
# City not found. Skipping...
# Processing Record 14 of Set 9 | garowe
# Processing Record 15 of Set 9 | maniitsoq
# Processing Record 16 of Set 9 | hobyo
# Processing Record 17 of Set 9 | arlit
# Processing Record 18 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 19 of Set 9 | leninskoye
# Processing Record 20 of Set 9 | dehloran
# Processing Record 21 of Set 9 | salamiyah
# Processing Record 22 of Set 9 | mizdah
# Processing Record 23 of Set 9 | iqaluit
# Processing Record 24 of Set 9 | pauini
# Processing Record 25 of Set 9 | quelimane
# Processing Record 26 of Set 9 | nuuk
# Processing Record 27 of Set 9 | bystryy istok
# Processing Record 28 of Set 9 | beringovskiy
# Processing Record 29 of Set 9 | yulara
# Processing Record 30 of Set 9 | shiroishi
# Processing Record 31 of Set 9 | vestmannaeyjar
# Processing Record 32 of Set 9 | sibu
# Processing Record 33 of Set 9 | amuntai
# Processing Record 34 of Set 9 | norman wells
# Processing Record 35 of Set 9 | semey
# Processing Record 36 of Set 9 | college
# Processing Record 37 of Set 9 | rybnaya sloboda
# Processing Record 38 of Set 9 | camocim
# Processing Record 39 of Set 9 | itarema
# Processing Record 40 of Set 9 | jimenez
# Processing Record 41 of Set 9 | gwadar
# Processing Record 42 of Set 9 | mahibadhoo
# Processing Record 43 of Set 9 | yangambi
# Processing Record 44 of Set 9 | dhidhdhoo
# Processing Record 45 of Set 9 | sydney
# Processing Record 46 of Set 9 | payo
# Processing Record 47 of Set 9 | marmande
# Processing Record 48 of Set 9 | columbus
# Processing Record 49 of Set 9 | oistins
# Processing Record 50 of Set 9 | takoradi
# Processing Record 1 of Set 10 | kalmar
# Processing Record 2 of Set 10 | la ronge
# Processing Record 3 of Set 10 | plettenberg bay
# Processing Record 4 of Set 10 | maraa
# Processing Record 5 of Set 10 | krutinka
# Processing Record 6 of Set 10 | salon
# Processing Record 7 of Set 10 | flinders
# Processing Record 8 of Set 10 | lucea
# Processing Record 9 of Set 10 | le vauclin
# Processing Record 10 of Set 10 | bereda
# Processing Record 11 of Set 10 | smila
# Processing Record 12 of Set 10 | san patricio
# Processing Record 13 of Set 10 | bac lieu
# Processing Record 14 of Set 10 | nome
# Processing Record 15 of Set 10 | tamandare
# Processing Record 16 of Set 10 | udimskiy
# Processing Record 17 of Set 10 | buea
# Processing Record 18 of Set 10 | cayenne
# Processing Record 19 of Set 10 | dalmatovo
# Processing Record 20 of Set 10 | inirida
# Processing Record 21 of Set 10 | springville
# Processing Record 22 of Set 10 | seoul
# Processing Record 23 of Set 10 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 24 of Set 10 | broome
# Processing Record 25 of Set 10 | bagdarin
# Processing Record 26 of Set 10 | kartaly
# Processing Record 27 of Set 10 | sarakhs
# Processing Record 28 of Set 10 | dolinsk
# Processing Record 29 of Set 10 | nao-me-toque
# City not found. Skipping...
# Processing Record 30 of Set 10 | miri
# Processing Record 31 of Set 10 | balinad
# Processing Record 32 of Set 10 | shitanjing
# Processing Record 33 of Set 10 | sur
# Processing Record 34 of Set 10 | tibagi
# Processing Record 35 of Set 10 | longlac
# City not found. Skipping...
# Processing Record 36 of Set 10 | san jose
# Processing Record 37 of Set 10 | katangli
# Processing Record 38 of Set 10 | swellendam
# Processing Record 39 of Set 10 | arbagar
# Processing Record 40 of Set 10 | kushchevskaya
# Processing Record 41 of Set 10 | la ligua
# Processing Record 42 of Set 10 | carutapera
# Processing Record 43 of Set 10 | siemiatycze
# Processing Record 44 of Set 10 | camacha
# Processing Record 45 of Set 10 | ossora
# Processing Record 46 of Set 10 | kupang
# Processing Record 47 of Set 10 | george
# Processing Record 48 of Set 10 | tabou
# Processing Record 49 of Set 10 | labrea
# Processing Record 50 of Set 10 | biak
# Processing Record 1 of Set 11 | la plata
# Processing Record 2 of Set 11 | bollnas
# Processing Record 3 of Set 11 | talnakh
# Processing Record 4 of Set 11 | kadoma
# Processing Record 5 of Set 11 | abalak
# Processing Record 6 of Set 11 | alyangula
# Processing Record 7 of Set 11 | hovd
# Processing Record 8 of Set 11 | clyde river
# Processing Record 9 of Set 11 | hokitika
# Processing Record 10 of Set 11 | oranjemund
# Processing Record 11 of Set 11 | urusha
# Processing Record 12 of Set 11 | jacareacanga
# Processing Record 13 of Set 11 | rocha
# Processing Record 14 of Set 11 | sinegorye
# Processing Record 15 of Set 11 | lerwick
# Processing Record 16 of Set 11 | orange cove
# Processing Record 17 of Set 11 | la asuncion
# Processing Record 18 of Set 11 | sorland
# Processing Record 19 of Set 11 | egvekinot
# Processing Record 20 of Set 11 | san miguel
# Processing Record 21 of Set 11 | manuk mangkaw
# Processing Record 22 of Set 11 | lodwar
# Processing Record 23 of Set 11 | namatanai
# Processing Record 24 of Set 11 | roma
# Processing Record 25 of Set 11 | maneadero
# Processing Record 26 of Set 11 | cockburn town
# Processing Record 27 of Set 11 | husavik
# Processing Record 28 of Set 11 | sheridan
# Processing Record 29 of Set 11 | lavrentiya
# Processing Record 30 of Set 11 | tateyama
# Processing Record 31 of Set 11 | stolin
# Processing Record 32 of Set 11 | iguape
# Processing Record 33 of Set 11 | tuatapere
# Processing Record 34 of Set 11 | ballina
# Processing Record 35 of Set 11 | slave lake
# Processing Record 36 of Set 11 | naftah
# City not found. Skipping...
# Processing Record 37 of Set 11 | salgueiro
# Processing Record 38 of Set 11 | progreso
# Processing Record 39 of Set 11 | beppu
# Processing Record 40 of Set 11 | waingapu
# Processing Record 41 of Set 11 | pecos
# Processing Record 42 of Set 11 | bocana de paiwas
# Processing Record 43 of Set 11 | medvezhyegorsk
# Processing Record 44 of Set 11 | codrington
# Processing Record 45 of Set 11 | arona
# Processing Record 46 of Set 11 | healdsburg
# Processing Record 47 of Set 11 | lata
# Processing Record 48 of Set 11 | el vigia
# Processing Record 49 of Set 11 | hamilton
# Processing Record 50 of Set 11 | channel-port aux basques
# Processing Record 1 of Set 12 | rundu
# Processing Record 2 of Set 12 | ust-maya
# Processing Record 3 of Set 12 | urucui
# Processing Record 4 of Set 12 | norden
# Processing Record 5 of Set 12 | tlacolula
# Processing Record 6 of Set 12 | taltal
# Processing Record 7 of Set 12 | vite
# Processing Record 8 of Set 12 | maragogi
# Processing Record 9 of Set 12 | kamenka
# Processing Record 10 of Set 12 | front royal
# Processing Record 11 of Set 12 | ruatoria
# City not found. Skipping...
# Processing Record 12 of Set 12 | kodinsk
# Processing Record 13 of Set 12 | nacala
# Processing Record 14 of Set 12 | muros
# Processing Record 15 of Set 12 | zambezi
# Processing Record 16 of Set 12 | alekseyevsk
# Processing Record 17 of Set 12 | fethiye
# Processing Record 18 of Set 12 | jardim
# Processing Record 19 of Set 12 | poso
# Processing Record 20 of Set 12 | copiapo
# Processing Record 21 of Set 12 | hami
# Processing Record 22 of Set 12 | gimli
# Processing Record 23 of Set 12 | itororo
# Processing Record 24 of Set 12 | sokoni
# Processing Record 25 of Set 12 | staraya kulatka
# Processing Record 26 of Set 12 | ransang
# Processing Record 27 of Set 12 | kenai
# Processing Record 28 of Set 12 | santa maria
# Processing Record 29 of Set 12 | sukhobuzimskoye
# Processing Record 30 of Set 12 | zhaotong
# Processing Record 31 of Set 12 | singaraja
# Processing Record 32 of Set 12 | adjumani
# Processing Record 33 of Set 12 | yuzhno-kurilsk
# Processing Record 34 of Set 12 | temaraia
# City not found. Skipping...
# Processing Record 35 of Set 12 | mulchen
# Processing Record 36 of Set 12 | xining
# Processing Record 37 of Set 12 | shenjiamen
# Processing Record 38 of Set 12 | jablah
# Processing Record 39 of Set 12 | ixtapa
# Processing Record 40 of Set 12 | sept-iles
# Processing Record 41 of Set 12 | phumi samraong
# City not found. Skipping...
# Processing Record 42 of Set 12 | el badari
# City not found. Skipping...
# Processing Record 43 of Set 12 | charters towers
# Processing Record 44 of Set 12 | kununurra
# Processing Record 45 of Set 12 | sioux lookout
# Processing Record 46 of Set 12 | niltepec
# Processing Record 47 of Set 12 | grand river south east
# City not found. Skipping...
# Processing Record 48 of Set 12 | chhabra
# Processing Record 49 of Set 12 | greymouth
# Processing Record 50 of Set 12 | tomatlan
# Processing Record 1 of Set 13 | padang
# Processing Record 2 of Set 13 | dinar
# Processing Record 3 of Set 13 | verkhoyansk
# Processing Record 4 of Set 13 | yinchuan
# Processing Record 5 of Set 13 | damaturu
# Processing Record 6 of Set 13 | berdigestyakh
# Processing Record 7 of Set 13 | los llanos de aridane
# Processing Record 8 of Set 13 | pendleton
# Processing Record 9 of Set 13 | mombasa
# Processing Record 10 of Set 13 | urengoy
# Processing Record 11 of Set 13 | banjar
# Processing Record 12 of Set 13 | alanya
# Processing Record 13 of Set 13 | marigot
# Processing Record 14 of Set 13 | kudligi
# Processing Record 15 of Set 13 | izhma
# Processing Record 16 of Set 13 | le port
# Processing Record 17 of Set 13 | lensk
# Processing Record 18 of Set 13 | bandarbeyla
# Processing Record 19 of Set 13 | thinadhoo
# Processing Record 20 of Set 13 | benicarlo
# Processing Record 21 of Set 13 | dargaville
# Processing Record 22 of Set 13 | jiddah
# City not found. Skipping...
# Processing Record 23 of Set 13 | saint-denis
# Processing Record 24 of Set 13 | newport
# Processing Record 25 of Set 13 | omboue
# Processing Record 26 of Set 13 | joshimath
# Processing Record 27 of Set 13 | kulhudhuffushi
# Processing Record 28 of Set 13 | gushikawa
# Processing Record 29 of Set 13 | marfino
# Processing Record 30 of Set 13 | ormara
# Processing Record 31 of Set 13 | quevedo
# Processing Record 32 of Set 13 | hargeysa
# Processing Record 33 of Set 13 | del rio
# Processing Record 34 of Set 13 | high rock
# Processing Record 35 of Set 13 | lafia
# Processing Record 36 of Set 13 | kieta
# Processing Record 37 of Set 13 | faanui
# Processing Record 38 of Set 13 | vagay
# Processing Record 39 of Set 13 | prado
# Processing Record 40 of Set 13 | kokopo
# Processing Record 41 of Set 13 | sosnovo-ozerskoye
# Processing Record 42 of Set 13 | glendive
# Processing Record 43 of Set 13 | synya
# Processing Record 44 of Set 13 | meulaboh
# Processing Record 45 of Set 13 | buchanan
# Processing Record 46 of Set 13 | klyuchevskiy
# Processing Record 47 of Set 13 | ilebo
# Processing Record 48 of Set 13 | bukit bakri
# City not found. Skipping...
# Processing Record 49 of Set 13 | melo
# Processing Record 50 of Set 13 | zapolyarnyy
# Processing Record 1 of Set 14 | khorixas
# Processing Record 2 of Set 14 | anjozorobe
# Processing Record 3 of Set 14 | yarada
# Processing Record 4 of Set 14 | mandan
# Processing Record 5 of Set 14 | chimoio
# Processing Record 6 of Set 14 | ust-ishim
# Processing Record 7 of Set 14 | chardara
# Processing Record 8 of Set 14 | gigmoto
# Processing Record 9 of Set 14 | seredka
# Processing Record 10 of Set 14 | mgandu
# Processing Record 11 of Set 14 | korla
# Processing Record 12 of Set 14 | pandan
# Processing Record 13 of Set 14 | pangnirtung
# Processing Record 14 of Set 14 | marsh harbour
# Processing Record 15 of Set 14 | shubarshi
# Processing Record 16 of Set 14 | kawambwa
# Processing Record 17 of Set 14 | ijaki
# City not found. Skipping...
# Processing Record 18 of Set 14 | matay
# Processing Record 19 of Set 14 | falaleu
# City not found. Skipping...
# Processing Record 20 of Set 14 | gouyave
# Processing Record 21 of Set 14 | zagan
# Processing Record 22 of Set 14 | jian
# Processing Record 23 of Set 14 | celestun
# Processing Record 24 of Set 14 | mabai
# Processing Record 25 of Set 14 | kytlym
# City not found. Skipping...
# Processing Record 26 of Set 14 | onalaska
# Processing Record 27 of Set 14 | innisfail
# Processing Record 28 of Set 14 | verkh-usugli
# Processing Record 29 of Set 14 | porto murtinho
# Processing Record 30 of Set 14 | havelock
# Processing Record 31 of Set 14 | tirano
# Processing Record 32 of Set 14 | toliary
# City not found. Skipping...
# Processing Record 33 of Set 14 | sorong
# Processing Record 34 of Set 14 | kambam
# Processing Record 35 of Set 14 | ilo
# Processing Record 36 of Set 14 | grand-santi
# Processing Record 37 of Set 14 | te anau
# Processing Record 38 of Set 14 | gewane
# Processing Record 39 of Set 14 | the valley
# Processing Record 40 of Set 14 | rosamorada
# Processing Record 41 of Set 14 | grand gaube
# Processing Record 42 of Set 14 | deoria
# Processing Record 43 of Set 14 | mandalgovi
# Processing Record 44 of Set 14 | port hardy
# Processing Record 45 of Set 14 | birao
# Processing Record 46 of Set 14 | pingzhuang
# Processing Record 47 of Set 14 | flin flon
# Processing Record 48 of Set 14 | gamba
# Processing Record 49 of Set 14 | acapulco
# Processing Record 50 of Set 14 | potrero del llano
# Processing Record 1 of Set 15 | gizo
# Processing Record 2 of Set 15 | mezokovesd
# Processing Record 3 of Set 15 | thunder bay
# Processing Record 4 of Set 15 | san miguel de cauri
# Processing Record 5 of Set 15 | baie-comeau
# Processing Record 6 of Set 15 | irituia
# Processing Record 7 of Set 15 | tsiroanomandidy
# Processing Record 8 of Set 15 | pointe-noire
# Processing Record 9 of Set 15 | taiyuan
# Processing Record 10 of Set 15 | tyrma
# Processing Record 11 of Set 15 | sabang
# Processing Record 12 of Set 15 | mocuba
# Processing Record 13 of Set 15 | bilma
# Processing Record 14 of Set 15 | aksarka
# Processing Record 15 of Set 15 | darhan
# Processing Record 16 of Set 15 | maldonado
# Processing Record 17 of Set 15 | batticaloa
# Processing Record 18 of Set 15 | along
# Processing Record 19 of Set 15 | laguna
# Processing Record 20 of Set 15 | praia
# Processing Record 21 of Set 15 | akyab
# Processing Record 22 of Set 15 | leningradskiy
# Processing Record 23 of Set 15 | gurskoye
# City not found. Skipping...
# Processing Record 24 of Set 15 | ravar
# Processing Record 25 of Set 15 | wum
# Processing Record 26 of Set 15 | westport
# Processing Record 27 of Set 15 | sola
# Processing Record 28 of Set 15 | harda
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#Get the length of the data
len(city_data)
# Out:
# 672

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Teahupoo -17.8333 -149.2667     75.16        76          35
# 1           Sabla  12.7525    4.7077     91.33        25          75
# 2            Hilo  19.7297 -155.0900     85.28        83         100
# 3    Puerto Ayora  -0.7393  -90.3518     84.16        81          74
# 4         Ushuaia -54.8000  -68.3000     56.86        58          75
# 5        Bengkulu  -3.8004  102.2655     75.45        87          61
# 6  Kamphaeng Phet  16.2500   99.5000     79.12        61          12
# 7       Kavaratti  10.5669   72.6420     80.35        82         100
# 8     New Norfolk -42.7826  147.0587     53.89        72         100
# 9     Charlestown -32.9500  151.6667     66.11        95          36
#
#    Wind Speed Current Description Country                 Date
# 0       20.15          light rain      PF  2022-04-13 22:44:57
# 1        9.24       broken clouds      NG  2022-04-13 22:44:58
# 2        3.44          light rain      US  2022-04-13 22:38:31
# 3        9.24       broken clouds      EC  2022-04-13 22:40:00
# 4        5.75       broken clouds      AR  2022-04-13 22:36:33
# 5        3.80       broken clouds      ID  2022-04-13 22:38:50
# 6        1.01          few clouds      TH  2022-04-13 22:44:58
# 7       20.60     overcast clouds      IN  2022-04-13 22:44:59
# 8        1.01     overcast clouds      AU  2022-04-13 22:38:49
# 9        1.99    scattered clouds      AU  2022-04-13 22:44:59

# %%
#Reorder the DF columns
new_column_order = ["City","Country", "Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed", "Current Description"]

# Rearrange the column order in the DF
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Teahupoo      PF -17.8333 -149.2667     75.16        76          35
# 1           Sabla      NG  12.7525    4.7077     91.33        25          75
# 2            Hilo      US  19.7297 -155.0900     85.28        83         100
# 3    Puerto Ayora      EC  -0.7393  -90.3518     84.16        81          74
# 4         Ushuaia      AR -54.8000  -68.3000     56.86        58          75
# 5        Bengkulu      ID  -3.8004  102.2655     75.45        87          61
# 6  Kamphaeng Phet      TH  16.2500   99.5000     79.12        61          12
# 7       Kavaratti      IN  10.5669   72.6420     80.35        82         100
# 8     New Norfolk      AU -42.7826  147.0587     53.89        72         100
# 9     Charlestown      AU -32.9500  151.6667     66.11        95          36
#
#    Wind Speed Current Description
# 0       20.15          light rain
# 1        9.24       broken clouds
# 2        3.44          light rain
# 3        9.24       broken clouds
# 4        5.75       broken clouds
# 5        3.80       broken clouds
# 6        1.01          few clouds
# 7       20.60     overcast clouds
# 8        1.01     overcast clouds
# 9        1.99    scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Data2/WeatherPy_Database.csv"

city_data_df.to_csv(output_data_file, index_label="City_ID")
